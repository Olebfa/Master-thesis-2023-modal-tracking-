# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import sys
import os
src_path='../src'
if not src_path in sys.path:
    sys.path.insert(1,src_path)
from preposessing import *
from utils_OB import *
from _tracking import *
# %load_ext autoreload
import pickle
# %autoreload 2
from utils_JK import *
from _postprocessing import *

# %%
names=os.listdir('../../5hz_resampled_int_trans_clustered/')
print(len(names))
# Out:
# 3853

# %%
test_seg=names[2]
print(names[1020])
print(test_seg)
ts=import_converted_ts('../../5hz_resampled_int_trans_clustered/',test_seg)
# Out:
# HB141M-2015-03-13_01-35-18.pkl
# HB141M-2013-12-06_08-24-54.pkl

# %%
fig=PlotStabDiagFromTsObject(ts,display=False,xmax=1,figsize=(7,4))

# %%
fig2=plot_stab_from_KOMA(lambd=ts.lambd,display=False,xmax=1,figsize=(7,3),true_w=False)
fig2.suptitle('Output from Cov-ssi',size='medium')
fig2.subplots_adjust(top=0.94)
fig2.savefig('ex_satbiag_bridge.png',dpi=500,bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig3=plot_stab_from_KOMA(lambd=ts.lambd,display=False,xmax=1,figsize=(7,3),true_w=False,lambd_stab=ts.lambd_stab,stab_orders=ts.orders_stab)
fig3.suptitle('Result of initial removal of mathematical poles',size='medium')
fig3.subplots_adjust(top=0.94)
fig3.savefig('ex_satbiag_stable_bridge.png',dpi=500,bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig4=PlotStabDiagFromTsObject(ts,xmax=1,display=False,figsize=(7,3),true_w=False)
fig4.suptitle('Stabilization diagram with colorcoded clusters',fontsize='medium')
fig4.subplots_adjust(top=0.94)
fig4.savefig('ex_satbiag_cluster_bridge.png',dpi=500,bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig5=PlotStabDiagFromTsObject(ts,xmax=1,display=False,figsize=(7,3),true_w=False,color='mac',show_num=False)
# fig5.suptitle('Stabilization diagram with colorcoding by paralellity to the extracted referance shape',fontsize='medium')
fig5.subplots_adjust(top=0.94)
fig5.savefig('ex_satbiag_mac_bridge.png',dpi=500,bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig5=PlotStabDiagFromTsObject(ts,xmax=1,display=False,figsize=(7,4),true_w=False,color='damping_abs',show_num=False)
# fig5.suptitle('Stabilization diagram with colorcoding by paralellity to the extracted referance shape',fontsize='medium')
fig5.subplots_adjust(top=0.94)
fig5.savefig('ex_satbiag_mac_bridge.png',dpi=500,bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
w,phi,names = import_folder_for_tracking('../../5hz_resampled_int_trans_clustered/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\olebj\OneDrive - NTNU\00Master - Onedrive\OB ymse\modal-tracking-thesis-spring-2023\Simple Figures\0_bridge_Aoma figures.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/olebj/OneDrive%20-%20NTNU/00Master%20-%20Onedrive/OB%20ymse/modal-tracking-thesis-spring-2023/Simple%20Figures/0_bridge_Aoma%20figures.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> w,phi,names = import_folder_for_tracking('../../5hz_resampled_int_trans_clustered/')
#
# File c:\Users\olebj\OneDrive - NTNU\00Master - Onedrive\OB ymse\modal-tracking-thesis-spring-2023\Simple Figures\../src\preposessing.py:590, in import_folder_for_tracking(path_in)
#     588 file_path=os.path.join(path_in,entry)
#     589 if os.path.isfile(file_path):
# --> 590     ts=import_converted_ts(path_in,entry)
# ...
