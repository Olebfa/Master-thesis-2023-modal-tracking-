# %%
import numpy as np 
import matplotlib.pyplot as plt 
import sys
sys.path.insert(1, "../")
# from _shear_frame import ShearFrame_3D
from utils_OB import *
# import koma.oma, koma.plot
import random
# from scipy.signal import detrend, welch, resample

# %%
t=np.linspace(0,100,10000)

load=load_series(t)

load.create_load(1,'decreasing',0.2,0.5,0.01)

plt.figure(figsize=(10,3))
plt.plot(t,load.F)
print(np.average((load.F)))
# Out:
# -0.009355750426663721

# %%
plt.figure(figsize=(10,3))
plt.plot(t,load.F)

# %%
def ran_list(i):
    return[random.randint(1,10)for i in range(3)]
print(ran_list(1))

arr2=np.array([ran_list(i)for i in range(4)])

# print(arr1)
print(arr2)
# Out:
# [5, 10, 1]
# [[ 8  2  9]
#  [ 7  6  9]
#  [ 4 10  4]
#  [ 7  5  4]]
